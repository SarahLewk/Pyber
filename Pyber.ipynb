# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib notebook

# %%
#Reading both CSVs
city_csv = "Data/city_data.csv"
ride_csv = "Data/ride_data.csv"

city_df = pd.read_csv(city_csv)
ride_df = pd.read_csv(ride_csv)

# %%
city_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
ride_df.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
#Merging both csv files into one
Pyber_df = pd.merge(city_df, ride_df, on="city")
Pyber_df.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
#Average fare ($) per city (y axis)
avg_fare = Pyber_df.groupby('city')['type','fare'].mean()

# %%
#Caluculating city type count
city_type_sum = Pyber_df.groupby('type').sum()

# %%
#creating dataframe with just city type and fair
fare_perc_df = city_type_perc[['fare']].head()

#creating dataframe with just city type and rides
ride_perc_df = city_type_perc[['ride_id']].head()

#creating dataframe with just city type and drivers
drivers_perc_df = city_type_perc[['driver_count']].head()

# %%
#Total number of rides per city (x axis)
rides_per_city = Pyber_df.groupby('city')['ride_id'].count()

# %%
#Total number of drivers per city (by circle size)
drivers_per_city = Pyber_df.groupby('city')["type","driver_count"].sum()

# %%
#Total number of drivers per city (by circle size)
drivers_per_city_edit = Pyber_df.groupby(['city', 'type'])["driver_count"].sum()

# %%
#grouping data to show color assigned to each city type
Pyber_df.groupby(['city','type']).head()
# Out:
#                    city  driver_count   type                 date   fare  \
# 0           Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1           Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2           Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3           Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4           Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 28         Williamsstad            59  Urban  2018-01-23 17:51:24  19.62
# 29         Williamsstad            59  Urban  2018-03-29 21:43:04  35.58
# 30         Williamsstad            59  Urban  2018-02-13 20:07:49  33.72
# 31         Williamsstad            59  Urban  2018-05-01 01:26:21  26.81
# 32         Williamsstad            59  Urban  2018-02-23 17:42:40   4.68
# 51          Port Angela            67  Urban  2018-04-17 06:23:18  16.34
# 52          Port Angela            67  Urban  2018-03-31 15:22:26  30.77
# ...

# %%
#Recieved help from Charity on this below as well as color assigning based on data.
city_summary = pd.concat([rides_per_city, avg_fare, drivers_per_city], axis=1)
city_summary.head()
# Out:
#                ride_id       fare  driver_count
# city
# Amandaburgh         18  24.641667           216
# Barajasview         22  25.332273           572
# Barronchester       16  36.422500           176
# Bethanyland         18  32.956111           396
# Bradshawfurt        10  40.064000            70

# %%
#Combining calcualtions to create new dataframe called "city_summary_edit":

#Total number of drivers per city (by circle size)
drivers_per_city_edit = Pyber_df.groupby(['city', 'type'])["driver_count"].sum()
drivers_per_city_edit

#Average fare ($) per city (y axis)
avg_fare_edit = Pyber_df.groupby(['city', 'type'])['fare'].mean()
avg_fare_edit

#Total number of rides per city (x axis)
rides_per_city_edit = Pyber_df.groupby(['city', 'type'])['ride_id'].count()

city_summary_edit = pd.concat([rides_per_city_edit, avg_fare_edit, drivers_per_city_edit], axis=1)
city_summary_edit = city_summary_edit.reset_index()
city_summary_edit.head()
# Out:
#             city      type  ride_id       fare  driver_count
# 0    Amandaburgh     Urban       18  24.641667           216
# 1    Barajasview     Urban       22  25.332273           572
# 2  Barronchester  Suburban       16  36.422500           176
# 3    Bethanyland  Suburban       18  32.956111           396
# 4   Bradshawfurt     Rural       10  40.064000            70

# %%
#Counting the total number of rides
number_rides = Pyber_df.groupby(['type']).count()

# %%
#Totaling up the number of drivers
number_drivers = Pyber_df.groupby(['type']).sum()

# %%
#Assigning colors to type
colors = {'Urban':'lightcoral', 'Suburban':'lightskyblue', 'Rural':'gold' }

#Plotting my bubble chart
plt.scatter( city_summary_edit['ride_id'], city_summary_edit['fare'], city_summary_edit['driver_count'], label="Urban", edgecolors='k', alpha=0.7,
           c=city_summary_edit['type'].apply(lambda x: colors[x]))

#Create empty plot for second label on legend
plt.scatter( [], [], [], color='lightskyblue', label="Suburban", edgecolors='k', alpha=0.7)

#Create empty plot for third label on legend
plt.scatter( [], [], [], color='gold', label="Rural", edgecolors='k', alpha=0.7)

#Labeling my chart and adding gridlines
plt.title("Pyber Ride Sharing Data 2016")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.grid()


# Place a legend on the chart
lgnd = plt.legend(fontsize="small", mode="Expanded", labelspacing=0.5, loc="best",title="City Types", scatterpoints=1, numpoints=1)
lgnd = plt.legend(fontsize="small", mode="Expanded", labelspacing=0.5, loc="best",title="City Types", scatterpoints=1, numpoints=1)
lgnd = plt.legend(fontsize="small", mode="Expanded", labelspacing=0.5, loc="best",title="City Types", scatterpoints=1, numpoints=1)
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]

#Printing my bubble chart
plt.show()

# %%
#Plotting a pie chart for percentage of fare by city type:

#Creating my variables for my plot
fare_data = city_type_sum['fare']
labels = ["Rural","Suburban", "Urban" ]
cols = ['gold','lightskyblue','lightcoral']

#Creating my plot
plt.pie(fare_data, labels = labels, colors = cols, startangle = 155, shadow =True, explode=(0,0,0.1), autopct='%1.1f%%')

#Adding the title
plt.title("% of Total Fares by City Type")

#Printing my pie chart
plt.show()

# %%
#Plotting a pie chart for percentage of rides by city type:

#Creating my variables for my plot
ride_data = number_rides["ride_id"]
labels = ["Rural","Suburban", "Urban" ]
cols = ['gold','lightskyblue','lightcoral']

#Creating my plot
plt.pie(ride_data, labels = labels, colors = cols, startangle = 155, shadow =True, explode=(0,0,0.1), autopct='%1.1f%%')

#Adding the title
plt.title('% of Total Rides by City Type')

#Printing my pie chart
plt.show()

# %%
#Plotting a pie chart for percentage of drivers by city type:

#Creating my variables for my plot
driver_data = number_drivers["driver_count"]
labels = ["Rural","Suburban", "Urban" ]
cols = ['gold','lightskyblue','lightcoral']

#Creating my plot
plt.pie(driver_data, labels = labels, colors = cols, startangle = 155, shadow =True, explode=(0,0,0.1), autopct='%1.1f%%')

#Adding the title
plt.title('% of Total Drivers by City Type')

#Printing my pie chart
plt.show()


#Note: I'm not getting the same result as far as percentages are concernded compared to the homework example but....
#I feel like I calculated this according to the instructions.
